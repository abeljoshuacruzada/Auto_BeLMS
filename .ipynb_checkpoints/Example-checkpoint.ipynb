# %%
import pandas as pd
import matplotlib.pyplot as plt
from Auto_BeLMS import AutoBelms as abl
from Auto_BeLMS.MyKNNClassifier import MyKNNClassifier
from Auto_BeLMS.MyLogisticRegression import MyLogisticRegression
from Auto_BeLMS.MyLinearSVM import MyLinearSVM
from Auto_BeLMS.MySVM import MySVM
# Out:
# E:\Documents\MSDS\Term 2\ML1\Auto_BeLMS\AutoBelms.py:9: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
df = pd.read_table('fruit_data_with_colors.txt')
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
X = df.iloc[:, 3:]
y = df.iloc[:, 0]

# %% [markdown]
# ## Simulator

# %%
abl.simulate(X, y, abl.models, figsize=(10,5), confmat=True)
# Out:
# Training KNN Classifier
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# 21.80239701271057 seconds
# Training Logistic Regression L1
# HBox(children=(FloatProgress(value=0.0, max=340.0), HTML(value='')))
# 2.3311219215393066 seconds
# Training Logistic Regression L2
# HBox(children=(FloatProgress(value=0.0, max=340.0), HTML(value='')))
# 51.58662509918213 seconds
# Training Linear SVM L1
# HBox(children=(FloatProgress(value=0.0, max=340.0), HTML(value='')))
# 1.9669673442840576 seconds
# Training Linear SVM L2
# HBox(children=(FloatProgress(value=0.0, max=340.0), HTML(value='')))
# 2.9067118167877197 seconds
# Training Non-Linear SVM RBF
# HBox(children=(FloatProgress(value=0.0, max=380.0), HTML(value='')))
# 1.757066011428833 seconds
# C:\Users\abelj\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                     Model   Best Parameter  Accuracy Top Predictor  Train Time
# 0          KNN Classifier  n neighbors = 1  0.630000          mass   21.802397
# 1  Logistic Regression L1       C = 1000.0  0.710000        height    2.331122
# 2  Logistic Regression L2       C = 1000.0  0.823333         width   51.586625
# 3           Linear SVM L1          C = 1.5  0.680000        height    1.966967
# 4           Linear SVM L2          C = 0.1  0.546667         width    2.906712
# 5      Non-Linear SVM RBF    gamma = 1e-08  0.246667          mass    1.757066

# %% [markdown]
# ## KNN

# %%
knn = MyKNNClassifier(10)

# %%
df_train, df_test = knn.train_model(X, y, n_jobs=-1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))

# %%
ax = plt.gca()
knn.create_errorband_axes(ax=ax)
ax.set_xlabel(knn.setting)
# Out:
# Text(0.5, 0, 'n neighbors')

# %%
knn.get_toppredictors()
# Out:
#                 score
# mass         0.642424
# width        0.627273
# height       0.524242
# color_score  0.440909

# %%
knn.get_bestparameter()
# Out:
# 4

# %%
knn.get_metric(ax=plt.gca())
# Out:
# {'confmat': array([[2, 0, 2, 0],
#         [0, 2, 0, 0],
#         [1, 0, 4, 1],
#         [0, 0, 2, 1]], dtype=int64),
#  'report':               precision    recall  f1-score  support
#  1              0.666667  0.500000  0.571429      4.0
#  2              1.000000  1.000000  1.000000      2.0
#  3              0.500000  0.666667  0.571429      6.0
#  4              0.500000  0.333333  0.400000      3.0
#  accuracy       0.600000  0.600000  0.600000      0.6
#  macro avg      0.666667  0.625000  0.635714     15.0
#  weighted avg   0.611111  0.600000  0.594286     15.0,
#  'ax': <matplotlib.axes._subplots.AxesSubplot at 0x2221b091cc8>}

# %% [markdown]
# ## Logistic Regression

# %%
log = MyLogisticRegression(10)

# %%
df_train, df_test = log.train_model(X, y)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=170.0), HTML(value='')))

# %%
ax = plt.gca()
log.create_errorband_axes(ax=ax)
ax.set_xlabel(log.setting)
ax.set_xscale('log')

# %%
log.get_toppredictors()
# Out:
#                    weight
# width        3.706264e-13
# height       1.903053e-13
# mass         1.553041e-13
# color_score  1.212821e-14

# %%
log.get_bestparameter()
# Out:
# 1000.0

# %%
log.get_metric(ax=plt.gca())
# Out:
# {'confmat': array([[4, 0, 1, 0],
#         [0, 1, 0, 0],
#         [2, 0, 6, 0],
#         [0, 0, 0, 1]], dtype=int64),
#  'report':               precision  recall  f1-score  support
#  1              0.666667  0.8000  0.727273      5.0
#  2              1.000000  1.0000  1.000000      1.0
#  3              0.857143  0.7500  0.800000      8.0
#  4              1.000000  1.0000  1.000000      1.0
#  accuracy       0.800000  0.8000  0.800000      0.8
#  macro avg      0.880952  0.8875  0.881818     15.0
#  weighted avg   0.812698  0.8000  0.802424     15.0,
#  'ax': <matplotlib.axes._subplots.AxesSubplot at 0x2221c595888>}

# %% [markdown]
# ## Linear SVM

# %%
lsvm = MyLinearSVM(10)

# %%
df_train, df_test = lsvm.train_model(X, y)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=170.0), HTML(value='')))

# %%
ax = plt.gca()
lsvm.create_errorband_axes(ax=ax)
ax.set_xlabel(lsvm.setting)
ax.set_xscale('log')

# %%
lsvm.get_toppredictors()
# Out:
#                weight
# height       0.241010
# color_score  0.240974
# width        0.082785
# mass         0.014918

# %%
lsvm.get_bestparameter()
# Out:
# 1000.0

# %%
lsvm.get_metric(ax=plt.gca())
# Out:
# {'confmat': array([[3, 0, 4, 0],
#         [0, 2, 0, 0],
#         [2, 0, 1, 1],
#         [0, 0, 0, 2]], dtype=int64),
#  'report':               precision    recall  f1-score    support
#  1              0.600000  0.428571  0.500000   7.000000
#  2              1.000000  1.000000  1.000000   2.000000
#  3              0.200000  0.250000  0.222222   4.000000
#  4              0.666667  1.000000  0.800000   2.000000
#  accuracy       0.533333  0.533333  0.533333   0.533333
#  macro avg      0.616667  0.669643  0.630556  15.000000
#  weighted avg   0.555556  0.533333  0.532593  15.000000,
#  'ax': <matplotlib.axes._subplots.AxesSubplot at 0x2221a606b08>}

# %% [markdown]
# ## Non Linear SVM

# %%
svm = MySVM(10)

# %%
df_train, df_test = svm.train_model(X, y, kernel='rbf', degree=3, max_iter=1000, coef0=0.0, random_state=0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=190.0), HTML(value='')))

# %%
ax = plt.gca()
svm.create_errorband_axes(ax=ax)
ax.set_xlabel(svm.setting)
ax.set_xscale('log')

# %%
svm.get_toppredictors()
# Out:
#                 score
# mass         0.559091
# width        0.371212
# height       0.321212
# color_score  0.287879

# %%
svm.get_bestparameter()
# Out:
# 0.001

# %%
svm.get_metric(ax=plt.gca())
# Out:
# {'confmat': array([[3, 0, 0, 0],
#         [0, 2, 0, 0],
#         [2, 0, 3, 0],
#         [0, 0, 0, 5]], dtype=int64),
#  'report':               precision    recall  f1-score    support
#  1              0.600000  1.000000  0.750000   3.000000
#  2              1.000000  1.000000  1.000000   2.000000
#  3              1.000000  0.600000  0.750000   5.000000
#  4              1.000000  1.000000  1.000000   5.000000
#  accuracy       0.866667  0.866667  0.866667   0.866667
#  macro avg      0.900000  0.900000  0.875000  15.000000
#  weighted avg   0.920000  0.866667  0.866667  15.000000,
#  'ax': <matplotlib.axes._subplots.AxesSubplot at 0x2221c2cfd88>}
